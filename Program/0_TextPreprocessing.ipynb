# %% [markdown]
# # Load PubMed

# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt

# %%
PubMed_Articles_Location = "../Src/pubmed-CancerType_Top1-10-set_Output.xlsx"
PubMed_Articles = pd.read_excel(PubMed_Articles_Location)

PubMed_Articles.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     PUMID  \
# 0           0             0  29790681
# 1           1             1  27261907
# 2           2             2  29635240
# 3           3             3  30955514
# 4           4             4  26667338
#
#                                                Title  \
# 0  Multiple primary lung cancer: A literature rev...
# 1                       Epidemiology of Lung Cancer.
# 2                      Heterogeneity in Lung Cancer.
# 3                                       Lung Cancer.
# 4                      Lung Cancer in Never Smokers.
#
#                                             Abstract CancerType
# 0  Nowadays, lung cancer is a leading cause of de...       Lung
# 1  Lung cancer has been transformed from a rare d...       Lung
# 2  Lung cancer diagnosis is a challenge since it ...       Lung
# 3  Lung cancer is the world's leading cause of ca...       Lung
# 4  Lung cancer is predominantly associated with c...       Lung

# %%
PubMed_Articles['Content'] = PubMed_Articles['Title']+ ' ' + PubMed_Articles['Abstract']
PubMed_Articles
# Out:
#        Unnamed: 0  Unnamed: 0.1     PUMID  \
# 0               0             0  29790681
# 1               1             1  27261907
# 2               2             2  29635240
# 3               3             3  30955514
# 4               4             4  26667338
# ...           ...           ...       ...
# 99995        9995          9995   1942705
# 99996        9996          9996  16325414
# 99997        9997          9997  28039452
# 99998        9998          9998  13687923
# 99999        9999          9999   9733663
#
#                                                    Title  \
# 0      Multiple primary lung cancer: A literature rev...
# 1                           Epidemiology of Lung Cancer.
# 2                          Heterogeneity in Lung Cancer.
# 3                                           Lung Cancer.
# 4                          Lung Cancer in Never Smokers.
# ...                                                  ...
# 99995  [A clinico-pathological study of 69 cases afte...
# 99996                       Continent urinary diversion.
# 99997  Preoperative neutrophil-lymphocyte ratio can s...
# 99998  [Indication and results of partial bladder res...
# 99999  N-glucuronidation of benzidine and its metabol...
#
#                                                 Abstract CancerType  \
# 0      Nowadays, lung cancer is a leading cause of de...       Lung
# 1      Lung cancer has been transformed from a rare d...       Lung
# 2      Lung cancer diagnosis is a challenge since it ...       Lung
# 3      Lung cancer is the world's leading cause of ca...       Lung
# 4      Lung cancer is predominantly associated with c...       Lung
# ...                                                  ...        ...
# 99995  A clinico-pathological study was conducted on ...    Bladder
# 99996  During the last decade continent urinary diver...    Bladder
# 99997  The prognostic role of systemic inflammatory r...    Bladder
# 99998  The prognostic role of systemic inflammatory r...    Bladder
# 99999  Workers exposed to high levels of benzidine ha...    Bladder
#
#                                                  Content
# 0      Multiple primary lung cancer: A literature rev...
# 1      Epidemiology of Lung Cancer. Lung cancer has b...
# 2      Heterogeneity in Lung Cancer. Lung cancer diag...
# 3      Lung Cancer. Lung cancer is the world's leadin...
# 4      Lung Cancer in Never Smokers. Lung cancer is p...
# ...                                                  ...
# 99995  [A clinico-pathological study of 69 cases afte...
# 99996  Continent urinary diversion. During the last d...
# 99997  Preoperative neutrophil-lymphocyte ratio can s...
# 99998  [Indication and results of partial bladder res...
# 99999  N-glucuronidation of benzidine and its metabol...
#
# [100000 rows x 7 columns]

# %%
PubMed_Articles = PubMed_Articles.reindex(columns = ['PUMID','Title','Abstract','Content','CancerType'])
PubMed_Articles
# Out:
#           PUMID                                              Title  \
# 0      29790681  Multiple primary lung cancer: A literature rev...
# 1      27261907                       Epidemiology of Lung Cancer.
# 2      29635240                      Heterogeneity in Lung Cancer.
# 3      30955514                                       Lung Cancer.
# 4      26667338                      Lung Cancer in Never Smokers.
# ...         ...                                                ...
# 99995   1942705  [A clinico-pathological study of 69 cases afte...
# 99996  16325414                       Continent urinary diversion.
# 99997  28039452  Preoperative neutrophil-lymphocyte ratio can s...
# 99998  13687923  [Indication and results of partial bladder res...
# 99999   9733663  N-glucuronidation of benzidine and its metabol...
#
#                                                 Abstract  \
# 0      Nowadays, lung cancer is a leading cause of de...
# 1      Lung cancer has been transformed from a rare d...
# 2      Lung cancer diagnosis is a challenge since it ...
# 3      Lung cancer is the world's leading cause of ca...
# 4      Lung cancer is predominantly associated with c...
# ...                                                  ...
# 99995  A clinico-pathological study was conducted on ...
# 99996  During the last decade continent urinary diver...
# 99997  The prognostic role of systemic inflammatory r...
# 99998  The prognostic role of systemic inflammatory r...
# 99999  Workers exposed to high levels of benzidine ha...
#
#                                                  Content CancerType
# 0      Multiple primary lung cancer: A literature rev...       Lung
# 1      Epidemiology of Lung Cancer. Lung cancer has b...       Lung
# 2      Heterogeneity in Lung Cancer. Lung cancer diag...       Lung
# 3      Lung Cancer. Lung cancer is the world's leadin...       Lung
# 4      Lung Cancer in Never Smokers. Lung cancer is p...       Lung
# ...                                                  ...        ...
# 99995  [A clinico-pathological study of 69 cases afte...    Bladder
# 99996  Continent urinary diversion. During the last d...    Bladder
# 99997  Preoperative neutrophil-lymphocyte ratio can s...    Bladder
# 99998  [Indication and results of partial bladder res...    Bladder
# 99999  N-glucuronidation of benzidine and its metabol...    Bladder
#
# [100000 rows x 5 columns]

# %%
ClassIDMap = {'Lung': 1,
              'Breast':2,
              'Colorectal':3,
              'Prostate': 4,
              'Stomach':5,
              'Liver':6,
              'Oesophagus':7,
              'Cervix Uteri':8,
              'Thyroid':9,
              'Bladder': 10}
ClassIDMap
# Out:
# {'Lung': 1,
#  'Breast': 2,
#  'Colorectal': 3,
#  'Prostate': 4,
#  'Stomach': 5,
#  'Liver': 6,
#  'Oesophagus': 7,
#  'Cervix Uteri': 8,
#  'Thyroid': 9,
#  'Bladder': 10}

# %%
corpus, target_labels, target_names = (PubMed_Articles['Content'], [ClassIDMap[label] for label in PubMed_Articles['CancerType']], PubMed_Articles['CancerType'])
data_df = pd.DataFrame({'Article': corpus, 'Target Label': target_labels, 'Target Name': target_names})
print(data_df.shape)
data_df.head(10)
# Out:
# (100000, 3)
#                                              Article  Target Label Target Name
# 0  Multiple primary lung cancer: A literature rev...             1        Lung
# 1  Epidemiology of Lung Cancer. Lung cancer has b...             1        Lung
# 2  Heterogeneity in Lung Cancer. Lung cancer diag...             1        Lung
# 3  Lung Cancer. Lung cancer is the world's leadin...             1        Lung
# 4  Lung Cancer in Never Smokers. Lung cancer is p...             1        Lung
# 5  Lung cancer in persons with HIV. PURPOSE OF RE...             1        Lung
# 6  Epidemiology of Lung Cancer. Lung cancer conti...             1        Lung
# 7  Lung cancer screening: advantages, controversi...             1        Lung
# 8  Lung cancer: diagnosis and management. Lung ca...             1        Lung
# 9  Diagnosis and Molecular Classification of Lung...             1        Lung

# %% [markdown]
# # Text Preprocessing

# %%
import text_normalizer as tn
import nltk
stopword_list = nltk.corpus.stopwords.words('english')
# just to keep negation if any in bi-grams
stopword_list.remove('no')
stopword_list.remove('not')
#stopword_list.add('cancer')

# normalize our corpus
norm_corpus = tn.normalize_corpus(corpus=data_df['Article'], html_stripping=True, contraction_expansion=True, 
                                  accented_char_removal=True, text_lower_case=True, text_lemmatization=True, 
                                  text_stemming=False, special_char_removal=True, remove_digits=True,
                                  stopword_removal=True, stopwords=stopword_list)
data_df['Clean Article'] = norm_corpus
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-3ab5c16d7c04> in <module>
#      11                                   accented_char_removal=True, text_lower_case=True, text_lemmatization=True,
#      12                                   text_stemming=False, special_char_removal=True, remove_digits=True,
# ---> 13                                   stopword_removal=True, stopwords=stopword_list)
#      14 data_df['Clean Article'] = norm_corpus
#
# ~\PubMed_CancerTypes_MiddleProject\Program\text_normalizer.py in normalize_corpus(corpus, html_stripping, contraction_expansion, accented_char_removal, text_lower_case, text_stemming, text_lemmatization, special_char_removal, remove_digits, stopword_removal, stopwords)
#
# ~\PubMed_CancerTypes_MiddleProject\Program\text_normalizer.py in lemmatize_text(text)
#
# ~\Anaconda3\lib\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#     447             if not hasattr(proc, "__call__"):
#     448                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 449             doc = proc(doc, **component_cfg.get(name, {}))
#     450             if doc is None:
#     451                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.predict()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.greedy_parse()
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\model.py in predict(self, X)
#     129
#     130     def predict(self, X):
# --> 131         y, _ = self.begin_update(X, drop=None)
#     132         return y
#     133
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserModel.begin_update()
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserStepModel.__init__()
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~\Anaconda3\lib\site-packages\thinc\api.py in begin_update(seqs_in, drop)
#     293     def begin_update(seqs_in, drop=0.0):
#     294         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 295         X, bp_layer = layer.begin_update(layer.ops.flatten(seqs_in, pad=pad), drop=drop)
#     296         if bp_layer is None:
#     297             return layer.ops.unflatten(X, lengths, pad=pad), None
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~\Anaconda3\lib\site-packages\thinc\api.py in uniqued_fwd(X, drop)
#     377         )
#     378         X_uniq = layer.ops.xp.ascontiguousarray(X[ind])
# --> 379         Y_uniq, bp_Y_uniq = layer.begin_update(X_uniq, drop=drop)
#     380         Y = Y_uniq[inv].reshape((X.shape[0],) + Y_uniq.shape[1:])
#     381
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\layernorm.py in begin_update(self, X, drop)
#      60     def begin_update(self, X, drop=0.0):
#      61         if self.child is not None:
# ---> 62             X, backprop_child = self.child.begin_update(X, drop=0.0)
#      63         else:
#      64             backprop_child = None
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\maxout.py in begin_update(self, X__bi, drop)
#      74         if drop is not None:
#      75             drop *= self.drop_factor
# ---> 76         output__boc = self.ops.gemm(X__bi, W, trans2=True)
#      77         output__boc += self.b.reshape((self.nO * self.nP,))
#      78         output__boc = output__boc.reshape((output__boc.shape[0], self.nO, self.nP))
#
# KeyboardInterrupt:

# %%
data_df = data_df[['Article', 'Clean Article', 'Target Label', 'Target Name']]
data_df.head(10)

# %%
data_df = data_df.replace(r'^(\s?)+$', np.nan, regex=True)
data_df = data_df.dropna().reset_index(drop=True)

# %%
data_df.to_csv('../Output/PubMed_CleanArticles_Top1-10_cancerTypes.csv', encoding='utf-8',index=False)
